# %%
print(5+5)
# Out:
# 10

# %%
import pandas as pd
data = {
    "Name": ["Aman", "Riya", "Karan"],
    "Age": [25, 30, 22],
    "City": ["Delhi", "Mumbai", "chennai"]
}

df = pd.DataFrame(data)

# drop a column
df1 = df.drop("City", axis = 1)

# drop a row (index1)
df2 = df.drop(1)

print(df1)
# Out:
#     Name  Age
# 0   Aman   25
# 1   Riya   30
# 2  Karan   22

# %%
import pandas as pd
data = {
    "Name": ["Aman", "Riya", "Karan"],
    "Age": [25, 30, 22],
}

df = pd.DataFrame(data)

df1 = df.dropna()

df2 = df.dropna(how = "all")

df3 = df.dropna(axis = 1)

print(df1)
# Out:
#     Name  Age
# 0   Aman   25
# 1   Riya   30
# 2  Karan   22

# %%
import pandas as pd
data = {
    "name": ["Aman", "Riya", "Karan"],
    "age": [25, 30, 22],
}

df = pd.DataFrame(data)

df1 = df.fillna(0)

df["age"] = df["age"].fillna(df["age"].mean())

df2 = df.fillna(method = "ffill")
print(df1)
# Out:
#     name  age
# 0   Aman   25
# 1   Riya   30
# 2  Karan   22
# C:\Users\Webdox\AppData\Local\Temp\ipykernel_10524\64787811.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2 = df.fillna(method = "ffill")

# %%
import pandas as pd
data = {
    "Name": ["Aman", "Riya", "Karan"],
    "City": ["Delhi", "Mumbai", "Delhi"]
}

df = pd.DataFrame(data)

df1 = df.replace("Delhi","New Delhi")

df2 = df.replace({"Delhi": "ND", "Mumbai":"MB"})

print(df1)
# Out:
#     Name       City
# 0   Aman  New Delhi
# 1   Riya     Mumbai
# 2  Karan  New Delhi

# %%
import pandas as pd
data = {
    "name": ["Riya", "Karan"],
    "age": [30, 22]
}

df = pd.DataFrame(data)

df1 = df.rename(columns = {"name":"full_name"})

df2 = df.rename(index = {0: "row1", 1:"row2"})

print(df1)
# Out:
#   full_name  age
# 0      Riya   30
# 1     Karan   22

# %%
import pandas as pd
data = {
    "age": [25, 30, 22]
}

df = pd.DataFrame(data)

df["age"] = df["age"].astype(int)

print(df)
# Out:
#    age
# 0   25
# 1   30
# 2   22

# %%
import pandas as pd
data = {
    "name": ["Aman", "Riya", "Aman"],
    "age": [25, 30, 25],
}

df = pd.DataFrame(data)

df1 = df.duplicated()

print(df1)
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
import pandas as pd
data = {
    "name": ["Aman", "Riya", "Karan"],
    "age": [25, 30, 22],
}

df = pd.DataFrame(data)

df1 = df.drop_duplicates()

df2 = df.drop_duplicates(keep = "last")
print(df1)
# Out:
#     name  age
# 0   Aman   25
# 1   Riya   30
# 2  Karan   22

# %%
import pandas as pd
import numpy as np

# Messy Sales Dataset
data = {
    "Order_ID": ["1001", "1002", "1003", "1004", "1005", "1006", None, "1008", "1009", "1010"],
    
    "Customer_Name": ["Aman", "Riya", "Karan", "Aman", None, "Priya", "Rohit", "Riya", "Karan", "Aman"],
    
    "Product": ["Laptop", "Mobile", "Tablet", "Laptop", "Mobile", "Tablet", "Laptop", "Mobile", None, "Tablet"],
    
    "Category": ["Electronics", "electronics", "Electronics", "ELECTRONICS", "Electronics", None, "Electronics", "electronics", "Electronics", "ELECTRONICS"],
    
    "Price": ["50000", "20000", "15000", "50000", "20000", "15000", "50000", "twenty thousand", "15000", None],
    
    "Quantity": [1, 2, None, 1, 2, 1, 1, 2, 1, None],
    
    "Order_Date": ["2024-01-10", "2024/02/15", "15-03-2024", "2024-01-10", None, "2024-04-18", "2024-05-01", "2024-06-11", "2024-07-20", "2024-08-25"],
    
    "Payment_Method": ["Credit Card", "Debit Card", "UPI", "Credit Card", "Cash", "UPI", None, "Debit Card", "UPI", "Cash"],
    
    "Discount": [10, None, 5, 10, 0, 5, None, 10, 5, 0],
    
    "Total_Amount": ["50000", "40000", "15000", "50000", "40000", None, "50000", "40000", "15000", "15000"]
}

df = pd.DataFrame(data)

# print(df.info())
# print(df.insull().sum())

# df = df.drop_duplicates()
# print(df)

# df["Customer_Name"]=df["Customer_Name"].fillna("Unknown")
# print(df)

# df["City"] = df["City"].fillna("Unknown")
# print(df)

# df["Age"] = df.["Age"].fillna(df["Age"].mean())
# print(df)

print(df)
# Out:
#   Order_ID Customer_Name Product     Category            Price  Quantity  \
# 0     1001          Aman  Laptop  Electronics            50000       1.0
# 1     1002          Riya  Mobile  electronics            20000       2.0
# 2     1003         Karan  Tablet  Electronics            15000       NaN
# 3     1004          Aman  Laptop  ELECTRONICS            50000       1.0
# 4     1005          None  Mobile  Electronics            20000       2.0
# 5     1006         Priya  Tablet         None            15000       1.0
# 6     None         Rohit  Laptop  Electronics            50000       1.0
# 7     1008          Riya  Mobile  electronics  twenty thousand       2.0
# 8     1009         Karan    None  Electronics            15000       1.0
# 9     1010          Aman  Tablet  ELECTRONICS             None       NaN
#
#    Order_Date Payment_Method  Discount Total_Amount
# 0  2024-01-10    Credit Card      10.0        50000
# 1  2024/02/15     Debit Card       NaN        40000
# ...

# %%
import pandas as pd

data = {
    "Department": ["IT", "IT", "HR", "HR", "Finance", "Finance", "IT"],
    "Employee": ["Aman", "Riya", "Karan", "Simran", "Raj", "Neha", "Arjun"],
    "Salary": [50000, 60000, 45000, 40000, 70000, 65000, 55000],
    "Experience": [2, 3, 1, 2, 5, 4, 3]
}

df = pd.DataFrame(data)

# grouped = df.groupby("Department")
# print(grouped["Salary"].mean())

# result = df.groupby("Department").agg({
#     "Salary": ["sum", "mean", "max"],
#     "Experience": ["mean", "max"]
# })
# print(result)

# df["Dept_Avg_Salary"] = df.groupby("Department")["Salary"].transform("mean")
# print(df)

# filtered = df.groupby("Department").filter(lambda x: x["Salary"].mean() > 50000)
# print(filtered)

print(df)
# Out:
#   Department Employee  Salary  Experience
# 0         IT     Aman   50000           2
# 1         IT     Riya   60000           3
# 2         HR    Karan   45000           1
# 3         HR   Simran   40000           2
# 4    Finance      Raj   70000           5
# 5    Finance     Neha   65000           4
# 6         IT    Arjun   55000           3

# %%
#CHATGPT2222222

# %%
#1
# import pandas as pd

# data = {
#     'Name': ['Aman', 'Riya', 'Karan', 'Simran', 'Aman'],
#     'Age': [23, 25, 24, 22, 23],
#     'Department': ['IT', 'HR', 'IT', 'Finance', 'IT'],
#     'Salary': [50000, 60000, 55000, 45000, 50000]
# }

# df = pd.DataFrame(data)

# df.head()
# df.tail()
# df.sample(2)
# df.info()
# df.describe()
# df.shape
# df.columns
# df.index
# df.dtypes
# df.nunique()
# df['Department'].value_counts()


# df.head()
# df.info()
# df.isnull().sum()

# %%
#2
# import pandas as pd

# data = {
#     'Product': ['Laptop', 'Phone', 'Tablet', 'Monitor', 'Phone'],
#     'Price': [80000, 30000, 20000, 15000, 32000],
#     'Sales': [10, 25, 15, 8, 30]
# }
# df = pd.DataFrame(data)

# df.sort_values(by='Price')
# df.sort_values(by='Sales', ascending=False)
# df.sort_values(by=['Product', 'Price'])
# df.sort_index(ascending=False)
# df['Sales_Rank'] = df['Sales'].rank()
# df
# df['Rank'] = df['Sales'].rank(ascending=False)
# df['Rank'] = df['Sales'].rank(method='dense')
# df

# %%
#3
# import pandas as pd

# data = {
#     'Sales': [100, 200, 150, 300, 250],
#     'Profit': [20, 50, 30, 80, 60],
#     'Orders': [5, 10, 7, 12, 9]
# }

# df = pd.DataFrame(data)

# df.mean()
# df.median()
# df.mode()
# df.sum()
# df.min()
# df.max()
# df.std()
# df.var()
# df.corr()
# df.cov()

# df.describe()
# df.corr()
# df['Sales'].mean()
# df['Profit'].sum()

# %%
#4
# import pandas as pd

# data = {
#     'Name': ['AMAN SHARMA', 'riya singh', 'Karan Kumar', 'Simran KAUR'],
#     'Email': ['AMAN@GMAIL.COM', 'riya@yahoo.com', 'karan@outlook.com', 'simran@GMAIL.com'],
#     'City': ['Delhi', 'Mumbai', 'delhi', 'PUNJAB']
# }
# df = pd.DataFrame(data)

# df['Name'] = df['Name'].str.lower()
# df['City'] = df['City'].str.upper()
# df[df['Email'].str.contains('gmail')]
# df[df['Email'].str.contains('gmail', case=False)]
# df['Email'] = df['Email'].str.replace('GMAIL', 'gmail')
# df['First_Name'] = df['Name'].str.split().str[0]
# df['Name_Length'] = df['Name'].str.len()


# # clean emails
# df['Email'] = df['Email'].str.lower()
# # filter gmail users
# gmail_users = df[df['Email'].str.contains('gmail')]
# # extract email domain
# df['Domain'] = df['Email'].str.split('@').str[1]
# # name cleanup
# df['Name'] = df['Name'].str.lower()
# # length check
# df['Name_Length'] = df['Name'].str.len()

# %%
# 5
# import pandas as pd

# df = pd.read_csv("data.csv")
# df = pd.read_excel("data.xlsx")
# df = pd.read_excel("data.xlsx", sheet_name="Sheet1")
# df = pd.read_json("data.json")


# [
#   {"Name": "Aman", "Sales": 100},
#   {"Name": "Riya", "Sales": 200}
# ]


# import sqlite3
# conn = sqlite3.connect("database.db")
# df = pd.read_sql("SELECT * FROM customers", conn)


# url = "https://example.com"
# tables = pd.read_html(url)
# df = tables[0]


# df = pd.read_clipboard()


# # Load data
# df = pd.read_csv("products.csv")

# # Quick check
# df.head()
# df.info()

# # Clean
# df.dropna(inplace=True)

# %%
# import pandas as pd

# data = {
#     "Date": ["2026-05-01", "2026-05-02", "2026-05-03", "2026-05-04"],
#     "Sales": [1000, 1200, 900, 1500]
# }

# df = pd.DataFrame(data)
# # print(df)

# df["Date"] = pd.to_datetime(df["Date"])
# print(df.dtypes)

# df["Date"] = pd.to_datetime(df["Date"])
# df = df.set_index("Date")
# monthly_sales = df.resample('M').sum()
# print(monthly_sales)

# weekly_avg = df.resample('W').mean()
# print(weekly_avg)

# df["Previous_Sales"] = df["Sales"].shift(1)
# print(df)

# df["Growth"] = df["Sales"] - df["Sales"].shift(1)
# print(df)

# df = df.tz_localize('Asia/Kolkata')
# print(df.index)

# df = df.tz_convert('US/Eastern')
# print(df.index)

# %%
# import pandas as pd

# data = {
#     "Date": ["2026-05-01", "2026-05-02", "2026-05-03"],
#     "Revenue": [5000, 7000, 6500]
# }

# df = pd.DataFrame(data)

# # convert to datetime
# df["Date"] = pd.to_datetime(df["Date"])

# # set index
# df = df.set_index("Date")

# # previous revenue
# df["Previous_Revenue"] = df["Revenue"].shift(1)

# # growth
# df["Growth"] = df["Revenue"] - df["Previous_Revenue"]

# # monthly report
# monthly = df.resample("M").sum()

# print(monthly)

# %%
# import pandas as pd
# import numpy as np

# data = {
#     "Name": ["Aman", "Riya", "Karan", None],
#     "Age": [23, 25, np.nan, 22],
#     "Salary": [25000, 50000, 120000, 30000]
# }

# df = pd.DataFrame(data)

# print(df)

# new_df = df.copy()
# print(new_df)

# new_df = df
# new_df["Age"] = 0

# df.isnull()

# df.isnull().sum()

# df.notnull()

# df.query("Salary > 30000")

# df.query("Salary > 30000 and Age > 24")

# df[(df["Salary"] > 30000) & (df["Age"] > 24)]

# df.eval("Bonus = Salary * 0.10")

# df.eval("Tax = Salary * 0.05")

# df["Salary"] = df["Salary"].clip(lower=30000, upper=100000)
# print(df)

# check missing values
# df.isnull().sum()

# # filter high salary employees
# high_salary = df.query("Salary > 40000")

# # calculate bonus
# df.eval("Bonus = Salary * 0.10")

# # limit extreme salary values
# df["Salary"] = df["Salary"].clip(30000, 100000)

# # create safe copy
# clean_df = df.copy()
